# %% [markdown]
# # Pagerank

# %% [markdown]
# ## Running Locally

# %%
# !python pagerank.py -r local soc-Epinions1.txt --output-dir=pagerank_out --no-output
# Out:
# Using configs in /Users/Baran/.mrjob.conf
# No configs specified for local runner
# Creating temp directory /var/folders/r7/428czl1x409_xdrj8zycbkyh0000gn/T/pagerank.Baran.20190414.142330.946255
# Running step 1 of 9...
# Running step 2 of 9...
# Running step 3 of 9...
# Running step 4 of 9...
# Running step 5 of 9...
# Running step 6 of 9...
# Running step 7 of 9...
# Running step 8 of 9...
# Running step 9 of 9...
# job output is in pagerank_out
# Removing temp directory /var/folders/r7/428czl1x409_xdrj8zycbkyh0000gn/T/pagerank.Baran.20190414.142330.946255...

# %%
# Check the output
# !cat pagerank_out/part-00000
# Out:
# "18"	2995313679751.549
# "4415"	61975938753.25651
# "737"	42091866128.129974
# "790"	20927721115.52191
# "1753"	19697489063.471207
# "143"	19261836107.15933
# "1719"	18812892387.333763
# "136"	9817756599.149992
# "751"	9630695685.439314
# "118"	4685741153.568681

# %% [markdown]
# Script can be ran with other iteration numbers

# %%
# !python pagerank.py -r local soc-Epinions1.txt --iterations=10 --output-dir=pagerank_out --no-output
# Out:
# Using configs in /Users/Baran/.mrjob.conf
# No configs specified for local runner
# Creating temp directory /var/folders/r7/428czl1x409_xdrj8zycbkyh0000gn/T/pagerank.Baran.20190414.142404.212328
# Running step 1 of 14...
# Running step 2 of 14...
# Running step 3 of 14...
# Running step 4 of 14...
# Running step 5 of 14...
# Running step 6 of 14...
# Running step 7 of 14...
# Running step 8 of 14...
# Running step 9 of 14...
# Running step 10 of 14...
# Running step 11 of 14...
# Running step 12 of 14...
# Running step 13 of 14...
# Running step 14 of 14...
# job output is in pagerank_out
# Removing temp directory /var/folders/r7/428czl1x409_xdrj8zycbkyh0000gn/T/pagerank.Baran.20190414.142404.212328...

# %% [markdown]
# ## Running on AWS EMR

# %%
# !python pagerank.py -r emr s3://baran-pagerank/input/soc-Epinions1.txt --output-dir=s3://baran-pagerank/pagerank_out --no-output
# Out:
# Using configs in /Users/Baran/.mrjob.conf
# Auto-created temp S3 bucket mrjob-bf75266d6f96a9b2
# Using s3://mrjob-bf75266d6f96a9b2/tmp/ as our temp dir on S3
# Creating temp directory /var/folders/r7/428czl1x409_xdrj8zycbkyh0000gn/T/pagerank.Baran.20190414.142448.682101
# writing master bootstrap script to /var/folders/r7/428czl1x409_xdrj8zycbkyh0000gn/T/pagerank.Baran.20190414.142448.682101/b.sh
# Copying local files to s3://mrjob-bf75266d6f96a9b2/tmp/pagerank.Baran.20190414.142448.682101/files/...
# Created new cluster j-A3YWF1M8YDUR
# Added EMR tags to cluster j-A3YWF1M8YDUR: __mrjob_label=pagerank, __mrjob_owner=Baran, __mrjob_version=0.6.7
# Waiting for Step 1 of 9 (s-1X1M3ZNIJG6JW) to complete...
#   PENDING (cluster is STARTING)
#   PENDING (cluster is STARTING)
#   PENDING (cluster is STARTING)
#   PENDING (cluster is STARTING: Configuring cluster software)
#   PENDING (cluster is BOOTSTRAPPING: Running bootstrap actions)
# ...
